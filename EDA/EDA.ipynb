# %%
import logging
from sqlalchemy.engine import URL
from sqlalchemy.sql import text
import coloredlogs
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os
import pandas as pd
import seaborn as sns

# %%
load_dotenv()
# Out:
# True

# %%
url_object = URL.create(
    "postgresql",
    username=os.getenv('USER'),
    password=os.getenv('PASS'),  # plain (unescaped) text
    host=os.getenv('HOST'),
    database=os.getenv('SCHEMA'),
)

# %%
#crear engine
engine = create_engine(url_object)

# %%
def query(postgresql_query):
    assert type(postgresql_query) == str
    #conectarse
    conn = engine.connect() 
    my_query = text(postgresql_query)
    resultSet = conn.execute(my_query).fetchall()
    #cerrar conexion
    conn.close()
    return resultSet

# %%
save = query('SELECT * FROM "AgileBuyings" LIMIT 1000')
df = pd.DataFrame(save)
display(df)
# Out:
#                   code                                               name  \
# 0       5178-528-COT21          Mantencion y traslado de equipo sp 802540
# 1       3130-146-COT21                                 TUBO CONECTOR SIMS
# 2        3223-25-COT21                              SERVICIOS DE TRASLADO
# 3    1002772-154-COT21  BOLSA EXTRACTORA ESPECIMEN 15MM, CAPACIDAD 150...
# 4    1058141-315-COT21  BIFOSFATO SODIO ENEMA AD [217P033] BIFOSFATO S...
# ..                 ...                                                ...
# 995      2929-62-COT21  Materiales de Construcción para Ayuda Social R...
# 996  1047027-111-COT21                      VORICONAZOL INYECTABLE 200 MG
# 997  1063538-371-COT21   ADQ. TUBO TAPA LILA 6 ML PARA BANCO SANGRE HBSJO
# 998     3995-245-COT21                   TABLETS ESC. ADOLFO QUIROZ F-687
# 999      5651-13-COT21                  SAE 039-2021 Silla escritorio PAU
#
#         status                                        description  \
# 0    Publicada         PR. INSTITUTO MILENIO, adjuntar cotización
# 1    Publicada  SE REQUIERE COTIZAR: TUBO CONECTOR SIMS DE VIN...
# 2    Publicada  SERVICIOS DE TRASLADO DESDE AEROPUERTO PUERTO ...
# 3    Publicada  *SE SOLICITA ADJUNTAR FICHA TÉCNICA Y FOTO DEL...
# 4    Publicada  PEDIDO FARMACIA MES MAYO\nADJUNTAR COTIZACION ...
# ..         ...                                                ...
# 995  Publicada  Se necesitan adquirir materiales de construcci...
# 996  Publicada                      VORICONAZOL INYECTABLE 200 MG
# 997  Publicada  ADQ.Tubo tapa lila 6 ml con EDTA PARA BANCO SA...
# 998  Publicada  AJUSTARSE A LAS ESPECIFICACIONES DEL MODELO SO...
# 999  Publicada  La Corporación Nacional Forestal de la región ...
#
#                                       shipping_address  \
# 0    sera indicado en orden de compra, Independenci...
# 1    AVENIDA BULNES 0256, Punta Arenas. Región de M...
# 2    AEROPUERTO EL TEPUAL REGION DE LOS LAGOS CHILE...
# 3    Mapocho 7432, Cerro Navia, piso -1 bodega de a...
# 4    SAN IGNACIO 725, Valparaíso. Región de Valparaíso
# ..                                                 ...
# 995  Bernardo Ohiggins 740, Palena. Región de los L...
# 996     SAN MARTIN 1270, Quilpué. Región de Valparaíso
# 997  GUILLERMO BUHLER 1765, Osorno. Región de los L...
# 998         BALMACEDA 250, Cauquenes. Región del Maule
# 999  Los productos adquiridos a través de la presen...
#
#                  publish_date              closing_date delivery_deadline  \
# 0   2021-04-21 13:15:28+00:00 2021-04-23 22:00:00+00:00           30 Días
# 1   2021-04-21 13:21:00+00:00 2021-04-28 21:00:00+00:00           10 Días
# 2   2021-04-21 13:15:58+00:00 2021-04-23 13:02:00+00:00            3 Días
# 3   2021-04-21 13:12:06+00:00 2021-04-22 15:00:00+00:00            2 Días
# 4   2021-04-21 13:22:49+00:00 2021-04-22 14:08:00+00:00            2 Días
# ..                        ...                       ...               ...
# 995 2021-04-21 20:05:03+00:00 2021-04-26 15:02:00+00:00            5 Días
# 996 2021-04-21 20:05:03+00:00 2021-04-22 20:07:00+00:00            2 Días
# 997 2021-04-21 20:04:58+00:00 2021-04-22 20:15:00+00:00            2 Días
# 998 2021-04-21 20:03:32+00:00 2021-04-22 21:00:00+00:00            5 Días
# 999 2021-04-21 20:03:58+00:00 2021-05-05 20:30:00+00:00           15 Días
#
#     currency  available_amount  ...       unit_id  \
# 0          $             732.0  ...  60.910.000-1
# 1          $             480.0  ...  61.102.029-5
# 2          $               1.2  ...  61.102.019-8
# 3          $               1.5  ...  61.608.205-1
# 4          $             500.0  ...  61.602.054-4
# ..       ...               ...  ...           ...
# 995        $             500.0  ...  69.231.300-3
# 996        $             850.0  ...  61.606.604-8
# 997        $             300.0  ...  61.602.260-1
# 998        $               1.5  ...  69.120.400-6
# 999        $             100.0  ...  61.313.000-4
#
#                            createdAt                        updatedAt url  \
# 0   2021-04-21 13:39:43.102000+00:00 2021-04-21 13:39:43.102000+00:00
# 1   2021-04-21 13:39:46.631000+00:00 2021-04-21 13:39:46.631000+00:00
# 2   2021-04-21 13:39:50.307000+00:00 2021-04-21 13:39:50.307000+00:00
# 3   2021-04-21 13:39:53.843000+00:00 2021-04-21 13:39:53.843000+00:00
# 4   2021-04-21 13:39:57.378000+00:00 2021-04-21 13:39:57.378000+00:00
# ..                               ...                              ...  ..
# 995 2021-04-21 20:06:42.149000+00:00 2021-04-21 20:06:42.149000+00:00
# 996 2021-04-21 20:06:45.951000+00:00 2021-04-21 20:06:45.951000+00:00
# 997 2021-04-21 20:06:49.481000+00:00 2021-04-21 20:06:49.481000+00:00
# 998 2021-04-21 20:06:56.381000+00:00 2021-04-21 20:06:56.381000+00:00
# 999 2021-04-21 20:06:59.925000+00:00 2021-04-21 20:06:59.925000+00:00
#
#     scrap_status oc_url oc_code         region unit_name org_name
# 0            NaN   None    None  No disponible
# 1            NaN   None    None  No disponible
# 2            NaN   None    None  No disponible
# 3            NaN   None    None  No disponible
# 4            NaN   None    None  No disponible
# ..           ...    ...     ...            ...       ...      ...
# 995          NaN   None    None  No disponible
# 996          NaN   None    None  No disponible
# 997          NaN   None    None  No disponible
# 998          NaN   None    None  No disponible
# 999          NaN   None    None  No disponible
#
# [1000 rows x 23 columns]
